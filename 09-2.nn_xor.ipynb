# %%
import numpy as np
import tensorflow as tf
# Out:
# 2024-03-06 14:52:25.799135: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

X = tf.constant(x_data)
Y = tf.constant(y_data)

W1 = tf.Variable(tf.random.normal([2, 2], name='weight1'))
b1 = tf.Variable(tf.random.normal([2]), name='bias1')
def layer1():
    return tf.math.sigmoid(tf.linalg.matmul(X, W1) + b1)

W2 = tf.Variable(tf.random.normal([2, 1], name='weight2'))
b2 = tf.Variable(tf.random.normal([1]), name='bias2')
def hypothesis():
    return tf.math.sigmoid(tf.linalg.matmul(layer1(), W2) + b2)

def cost():
    return -tf.reduce_mean(Y * tf.math.log(hypothesis()) + (1 - Y) * tf.math.log(1 - hypothesis()))

def train():
    return tf.keras.optimizers.SGD(learning_rate = 0.1).minimize(cost, var_list=[W1, b1, W2, b2])

def predicted():
    return tf.cast(hypothesis() > 0.5, dtype=tf.float32)

def accuracy():
    return tf.reduce_mean(tf.cast(tf.equal(predicted(), Y), dtype=tf.float32))

for step in range(10001):
    train()
    if step % 100 == 0:
        print(step, cost())
# Out:
# 0 tf.Tensor(0.7517467, shape=(), dtype=float32)
# 100 tf.Tensor(0.68924624, shape=(), dtype=float32)
# 200 tf.Tensor(0.6880656, shape=(), dtype=float32)
# 300 tf.Tensor(0.6866813, shape=(), dtype=float32)
# 400 tf.Tensor(0.684989, shape=(), dtype=float32)
# 500 tf.Tensor(0.68294907, shape=(), dtype=float32)
# 600 tf.Tensor(0.68050534, shape=(), dtype=float32)
# 700 tf.Tensor(0.6775621, shape=(), dtype=float32)
# 800 tf.Tensor(0.67396265, shape=(), dtype=float32)
# 900 tf.Tensor(0.6694707, shape=(), dtype=float32)
# 1000 tf.Tensor(0.66375136, shape=(), dtype=float32)
# 1100 tf.Tensor(0.65635216, shape=(), dtype=float32)
# 1200 tf.Tensor(0.64669484, shape=(), dtype=float32)
# 1300 tf.Tensor(0.6341013, shape=(), dtype=float32)
# 1400 tf.Tensor(0.6178561, shape=(), dtype=float32)
# 1500 tf.Tensor(0.59726375, shape=(), dtype=float32)
# 1600 tf.Tensor(0.5716873, shape=(), dtype=float32)
# 1700 tf.Tensor(0.5406649, shape=(), dtype=float32)
# 1800 tf.Tensor(0.5042312, shape=(), dtype=float32)
# 1900 tf.Tensor(0.46331, shape=(), dtype=float32)
# 2000 tf.Tensor(0.41978648, shape=(), dtype=float32)
# 2100 tf.Tensor(0.37605214, shape=(), dtype=float32)
# 2200 tf.Tensor(0.3343093, shape=(), dtype=float32)
# 2300 tf.Tensor(0.2960845, shape=(), dtype=float32)
# 2400 tf.Tensor(0.2621236, shape=(), dtype=float32)
# 2500 tf.Tensor(0.23254871, shape=(), dtype=float32)
# 2600 tf.Tensor(0.20709571, shape=(), dtype=float32)
# 2700 tf.Tensor(0.18531449, shape=(), dtype=float32)
# 2800 tf.Tensor(0.16670194, shape=(), dtype=float32)
# 2900 tf.Tensor(0.1507741, shape=(), dtype=float32)
# 3000 tf.Tensor(0.13709868, shape=(), dtype=float32)
# 3100 tf.Tensor(0.12530579, shape=(), dtype=float32)
# 3200 tf.Tensor(0.11508497, shape=(), dtype=float32)
# 3300 tf.Tensor(0.106179714, shape=(), dtype=float32)
# 3400 tf.Tensor(0.09837878, shape=(), dtype=float32)
# 3500 tf.Tensor(0.09150915, shape=(), dtype=float32)
# 3600 tf.Tensor(0.085428454, shape=(), dtype=float32)
# 3700 tf.Tensor(0.08001933, shape=(), dtype=float32)
# 3800 tf.Tensor(0.075185046, shape=(), dtype=float32)
# 3900 tf.Tensor(0.07084525, shape=(), dtype=float32)
# 4000 tf.Tensor(0.06693283, shape=(), dtype=float32)
# 4100 tf.Tensor(0.06339173, shape=(), dtype=float32)
# 4200 tf.Tensor(0.060174696, shape=(), dtype=float32)
# 4300 tf.Tensor(0.057241715, shape=(), dtype=float32)
# 4400 tf.Tensor(0.05455883, shape=(), dtype=float32)
# 4500 tf.Tensor(0.052097116, shape=(), dtype=float32)
# 4600 tf.Tensor(0.04983161, shape=(), dtype=float32)
# 4700 tf.Tensor(0.047740906, shape=(), dtype=float32)
# 4800 tf.Tensor(0.045806512, shape=(), dtype=float32)
# 4900 tf.Tensor(0.04401227, shape=(), dtype=float32)
# 5000 tf.Tensor(0.042344153, shape=(), dtype=float32)
# 5100 tf.Tensor(0.040789872, shape=(), dtype=float32)
# 5200 tf.Tensor(0.039338637, shape=(), dtype=float32)
# 5300 tf.Tensor(0.037980903, shape=(), dtype=float32)
# 5400 tf.Tensor(0.03670829, shape=(), dtype=float32)
# 5500 tf.Tensor(0.035513327, shape=(), dtype=float32)
# 5600 tf.Tensor(0.034389377, shape=(), dtype=float32)
# 5700 tf.Tensor(0.033330493, shape=(), dtype=float32)
# 5800 tf.Tensor(0.032331437, shape=(), dtype=float32)
# 5900 tf.Tensor(0.031387363, shape=(), dtype=float32)
# 6000 tf.Tensor(0.030494045, shape=(), dtype=float32)
# 6100 tf.Tensor(0.029647645, shape=(), dtype=float32)
# 6200 tf.Tensor(0.02884465, shape=(), dtype=float32)
# 6300 tf.Tensor(0.02808191, shape=(), dtype=float32)
# 6400 tf.Tensor(0.027356556, shape=(), dtype=float32)
# 6500 tf.Tensor(0.026665995, shape=(), dtype=float32)
# 6600 tf.Tensor(0.02600786, shape=(), dtype=float32)
# 6700 tf.Tensor(0.025379976, shape=(), dtype=float32)
# 6800 tf.Tensor(0.024780333, shape=(), dtype=float32)
# 6900 tf.Tensor(0.02420715, shape=(), dtype=float32)
# 7000 tf.Tensor(0.023658764, shape=(), dtype=float32)
# 7100 tf.Tensor(0.023133628, shape=(), dtype=float32)
# 7200 tf.Tensor(0.022630343, shape=(), dtype=float32)
# 7300 tf.Tensor(0.0221476, shape=(), dtype=float32)
# 7400 tf.Tensor(0.021684192, shape=(), dtype=float32)
# 7500 tf.Tensor(0.021239012, shape=(), dtype=float32)
# 7600 tf.Tensor(0.020811003, shape=(), dtype=float32)
# 7700 tf.Tensor(0.020399276, shape=(), dtype=float32)
# 7800 tf.Tensor(0.020002894, shape=(), dtype=float32)
# 7900 tf.Tensor(0.019621052, shape=(), dtype=float32)
# 8000 tf.Tensor(0.019253, shape=(), dtype=float32)
# 8100 tf.Tensor(0.01889797, shape=(), dtype=float32)
# 8200 tf.Tensor(0.018555317, shape=(), dtype=float32)
# 8300 tf.Tensor(0.018224444, shape=(), dtype=float32)
# 8400 tf.Tensor(0.017904771, shape=(), dtype=float32)
# 8500 tf.Tensor(0.0175957, shape=(), dtype=float32)
# 8600 tf.Tensor(0.017296782, shape=(), dtype=float32)
# 8700 tf.Tensor(0.017007474, shape=(), dtype=float32)
# 8800 tf.Tensor(0.016727358, shape=(), dtype=float32)
# 8900 tf.Tensor(0.016456034, shape=(), dtype=float32)
# 9000 tf.Tensor(0.016193088, shape=(), dtype=float32)
# 9100 tf.Tensor(0.015938114, shape=(), dtype=float32)
# 9200 tf.Tensor(0.015690811, shape=(), dtype=float32)
# 9300 tf.Tensor(0.015450802, shape=(), dtype=float32)
# 9400 tf.Tensor(0.015217813, shape=(), dtype=float32)
# 9500 tf.Tensor(0.01499152, shape=(), dtype=float32)
# 9600 tf.Tensor(0.014771648, shape=(), dtype=float32)
# 9700 tf.Tensor(0.014557934, shape=(), dtype=float32)
# 9800 tf.Tensor(0.014350164, shape=(), dtype=float32)
# 9900 tf.Tensor(0.0141480295, shape=(), dtype=float32)
# 10000 tf.Tensor(0.013951333, shape=(), dtype=float32)

# %%
h = hypothesis()
c = predicted()
a = accuracy()
print('hypothesis: ', h.numpy(), 'Correct: ', c.numpy(), 'Accuracy: ', a.numpy())
# Out:
# hypothesis:  [[0.01702509]
#  [0.9874062 ]
#  [0.9874075 ]
#  [0.01319949]] Correct:  [[0.]
#  [1.]
#  [1.]
#  [0.]] Accuracy:  1.0
